# %%
import pandas as pd
import numpy as np
import matplotlib as math
df = pd.read_csv ("/Users/elena/Desktop/stack-overflow-developer-survey-2024/survey_results_public.csv")
survey_schema = pd.read_csv ("/Users/elena/Desktop/stack-overflow-developer-survey-2024/survey_results_schema.csv")
df.head(20)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2                     I am a developer by profession
# 2            3                     I am a developer by profession
# 3            4                              I am learning to code
# 4            5                     I am a developer by profession
# 5            6                        I code primarily as a hobby
# 6            7  I am not primarily a developer, but I write co...
# 7            8                              I am learning to code
# 8            9                        I code primarily as a hobby
# 9           10                     I am a developer by profession
# 10          11  I used to be a developer by profession, but no...
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %% [markdown]
# 1. How many respondents completed the survey?

# %%
df.ResponseId.nunique()
# Out:
# 65437

# %% [markdown]
# 2. How many respondents answered all the questions?

# %%
##First, we convert the table with the survey results and the diagram into sets:
questions_results = df.columns
questions_schema = survey_schema.qname
print (questions_results)
print (questions_schema)
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)
# 0          MainBranch
# 1                 Age
# 2          Employment
# 3          RemoteWork
# 4               Check
#            ...
# 82     JobSatPoints_7
# 83     JobSatPoints_8
# 84     JobSatPoints_9
# 85    JobSatPoints_10
# 86    JobSatPoints_11
# Name: qname, Length: 87, dtype: object

# %%
##Next, we find the common elements in the sets:
results_and_schema = set(questions_results) & set(questions_schema)
print (results_and_schema)
# Out:
# {'Knowledge_3', 'Currency', 'Frustration', 'SurveyLength', 'CompTotal', 'Age', 'Knowledge_2', 'ProfessionalQuestion', 'SOComm', 'Knowledge_4', 'TBranch', 'DevType', 'TechEndorse', 'SOAccount', 'JobSatPoints_7', 'Employment', 'SOVisitFreq', 'BuildvsBuy', 'JobSatPoints_5', 'JobSatPoints_6', 'AISent', 'Knowledge_8', 'JobSatPoints_8', 'TimeSearching', 'Frequency_2', 'JobSatPoints_10', 'ICorPM', 'JobSatPoints_11', 'WorkExp', 'ProfessionalCloud', 'AIEthics', 'JobSatPoints_9', 'JobSatPoints_1', 'Knowledge_6', 'Check', 'JobSatPoints_4', 'AIChallenges', 'NEWSOSites', 'EdLevel', 'Industry', 'BuyNewTool', 'AIThreat', 'AISelect', 'SOPartFreq', 'JobSat', 'Country', 'Frequency_1', 'SOHow', 'ProfessionalTech', 'TechDoc', 'AIAcc', 'Frequency_3', 'AIBen', 'YearsCode', 'YearsCodePro', 'LearnCode', 'Knowledge_5', 'MainBranch', 'PurchaseInfluence', 'Knowledge_1', 'LearnCodeOnline', 'SurveyEase', 'Knowledge_7', 'Knowledge_9', 'OrgSize', 'RemoteWork', 'CodingActivities', 'AIComplex', 'TimeAnswering'}

# %%
##After combining the two sets of values, we remove from results_and_schema the rows that contain at least one zero value:
df.dropna (subset = results_and_schema).shape[0]
# Out:
# 6306

# %% [markdown]
# 3. What are the measures of central tendency for the respondents' work experience (WorkExp)?

# %%
mean = round(df['WorkExp'].mean(),0)
median = df['WorkExp'].median()
mode = df['WorkExp'].mode()
print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 11.0
# Median: 9.0
# Mode: 0    3.0
# Name: WorkExp, dtype: float64

# %% [markdown]
# 4. How many respondents work remotely?

# %%
df['RemoteWork'].str.contains('Remote').sum()
# Out:
# 20831

# %% [markdown]
# 5. What percentage of respondents program in Python?

# %%
round(df['LanguageHaveWorkedWith'].str.contains('Python').sum()/df.ResponseId.nunique()*100)
# Out:
# 47

# %% [markdown]
# 6. How many respondents learned to program through online courses?

# %%
df['LearnCode'].str.contains('Online Courses').sum()
# Out:
# 30271

# %% [markdown]
# 7. Among respondents who program in Python, grouped by country, what are the mean and median compensation amounts (ConvertedCompYearly) in each country?

# %%
##First, we remove the n/a values from the sample:
python = df['LanguageHaveWorkedWith'].str.contains('Python').dropna

# %%
##Next, we group Python users by country:
df_python_by_country = df_python_workers.groupby('Country')

# %%
##Now, we calculate the mean and median compensation amounts:
df_python_by_country ['ConvertedCompYearly'].agg(['mean', 'median'])
# Out:
#                                                mean    median
# Country
# Afghanistan                             5057.250000    3438.0
# Albania                                39207.545455   35341.0
# Algeria                                91836.700000    7120.0
# Andorra                               123517.000000  123517.0
# Angola                                  1366.333333    1754.0
# ...                                             ...       ...
# Venezuela, Bolivarian Republic of...   20729.411765   11400.0
# Viet Nam                               18803.281250   12288.5
# Yemen                                  16498.400000    5333.0
# Zambia                                 17054.400000    2280.0
# Zimbabwe                               29681.818182   18000.0
#
# [185 rows x 2 columns]

# %% [markdown]
# 8. What are the education levels of the 5 respondents with the highest compensation?

# %%
df.sort_values(by = 'ConvertedCompYearly', ascending = False).head()
##From the obtained results, we can see that the 5 respondents with the highest 
##compensation have education levels of Bachelor’s degree (2 respondents) and Doctorate (3 respondents).
# Out:
#        ResponseId                      MainBranch              Age  \
# 15837       15838  I am a developer by profession  25-34 years old
# 12723       12724  I am a developer by profession  25-34 years old
# 28379       28380  I am a developer by profession  18-24 years old
# 17593       17594  I am a developer by profession  35-44 years old
# 17672       17673  I am a developer by profession  25-34 years old
#
#                                               Employment  \
# 15837  Independent contractor, freelancer, or self-em...
# 12723  Employed, full-time;Independent contractor, fr...
# 28379                                Employed, full-time
# 17593                                Employed, full-time
# 17672                                Employed, full-time
#
#                                  RemoteWork   Check  \
# 15837                             In-person  Apples
# 12723  Hybrid (some remote, some in-person)  Apples
# 28379  Hybrid (some remote, some in-person)  Apples
# ...
